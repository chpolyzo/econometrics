# %%
# import necessary libraries
import pandas as pd
#from IPython.display import display
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data.csv') # read csv int a df
df.rename(columns={'Unnamed: 0': 'Year'}, inplace = True) # rename column 'Unnamed: 0'
df.dropna(inplace = True) # Drop null values 
df['Date'] = pd.to_datetime(df['Year'], format='%Y') # set datetime set on the year
df.set_index('Date', inplace=True) # Set the 'Year' column as the index
df = df.drop(columns=['Year']) # drop Year column

# %%
# read labels file to dictionary
with open('stata_dict.txt', 'r') as file:
        stata_vals_dict = eval(file.read())  # Use eval carefully for trusted input
        print(stata_vals_dict)

# create appropreate labels for the needs of my analyses

jrc_labels = list(df.columns) # save existing labels
stata_labels = list({k:v[1] for k, v in stata_vals_dict.items()}.values()) # create stata labels
#stata_labels.insert(0, 'Year') # insert year label
complete_labels = list({k:v[0] for k, v in stata_vals_dict.items()}.values()) # create complete labels
#complete_labels.insert(0, 'Year')
# Out:
# {'SOVGDE': ['Real labour productivity per person employed', 'realLabourProductivityPerPerso'], 'SNETD': ['Total Employment (workplace based, employed persons)', 'totalEmploymentWorkplaceBasedE'], 'SNPTD': ['Average annual population', 'averageAnnualPopulation'], 'SUVGD': ['GDP at current market prices', 'gdpAtCurrentMarketPrices'], 'RUWCD': ['Compensation of employees at current prices', 'compensationOfEmployeesAtCurre'], 'RUYNH': ['Current taxes on income and wealth', 'currentTaxesOnIncomeAndWealth'], 'RUIGT': ['Gross Fixed Capital Formation at current prices', 'grossFixedCapitalFormationAtCu'], 'ROKND': ['Capital Stock at constant prices', 'capitalStockAtConstantPrices'], 'RPDNN': ['Early leavers from education and training', 'earlyLeaversFromEducationAndTr']}

# %%
complete_labels
# Out:
# ['Real labour productivity per person employed',
#  'Total Employment (workplace based, employed persons)',
#  'Average annual population',
#  'GDP at current market prices',
#  'Compensation of employees at current prices',
#  'Current taxes on income and wealth',
#  'Gross Fixed Capital Formation at current prices',
#  'Capital Stock at constant prices',
#  'Early leavers from education and training']

# %%
labels = ["Productivity", 
          "Employment", 
          "Population", 
          "Gdp", 
          "Compensation", 
          "TaxesIncomeWealth", 
          "CapitalFormation", 
          "CapitalStock",
          "earlyLeavers"]

# %%
# display correlation
df.columns = labels
mat = df.corr(method = "spearman").round(2)

mat.style.background_gradient(cmap = "RdYlGn").format("{:.2f}")
# Out:
# <style type="text/css">
# #T_db71f_row0_col0, #T_db71f_row1_col1, #T_db71f_row2_col2, #T_db71f_row3_col3, #T_db71f_row4_col4, #T_db71f_row5_col5, #T_db71f_row6_col6, #T_db71f_row7_col7, #T_db71f_row8_col8 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_db71f_row0_col1, #T_db71f_row0_col2, #T_db71f_row0_col3, #T_db71f_row0_col4, #T_db71f_row0_col7, #T_db71f_row0_col8, #T_db71f_row2_col0, #T_db71f_row8_col5, #T_db71f_row8_col6 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_db71f_row0_col5, #T_db71f_row8_col7 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_db71f_row0_col6 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_db71f_row1_col0 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_db71f_row1_col2 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_db71f_row1_col3 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_db71f_row1_col4, #T_db71f_row3_col2, #T_db71f_row4_col2 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_db71f_row1_col5 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_db71f_row1_col6 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_db71f_row1_col7, #T_db71f_row5_col6 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_db71f_row1_col8 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_db71f_row2_col1 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_db71f_row2_col3, #T_db71f_row2_col4 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_db71f_row2_col5 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_db71f_row2_col6 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_db71f_row2_col7 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_db71f_row2_col8 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_db71f_row3_col0 {
#   background-color: #cc2627;
#   color: #f1f1f1;
# }
# #T_db71f_row3_col1 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_db71f_row3_col4, #T_db71f_row4_col3 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_db71f_row3_col5 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_db71f_row3_col6 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_db71f_row3_col7, #T_db71f_row7_col8 {
#   background-color: #9bd469;
#   color: #000000;
# }
# #T_db71f_row3_col8 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_db71f_row4_col0 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_db71f_row4_col1 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_db71f_row4_col5 {
#   background-color: #bd1726;
#   color: #f1f1f1;
# }
# #T_db71f_row4_col6 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_db71f_row4_col7 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_db71f_row4_col8, #T_db71f_row7_col4 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_db71f_row5_col0 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_db71f_row5_col1 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_db71f_row5_col2 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_db71f_row5_col3 {
#   background-color: #dc3b2c;
#   color: #f1f1f1;
# }
# #T_db71f_row5_col4 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_db71f_row5_col7 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_db71f_row5_col8 {
#   background-color: #d22b27;
#   color: #f1f1f1;
# }
# #T_db71f_row6_col0 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_db71f_row6_col1 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_db71f_row6_col2, #T_db71f_row7_col5 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_db71f_row6_col3, #T_db71f_row6_col4 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_db71f_row6_col5 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_db71f_row6_col7 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_db71f_row6_col8 {
#   background-color: #e44c34;
#   color: #f1f1f1;
# }
# #T_db71f_row7_col0 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_db71f_row7_col1 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_db71f_row7_col2 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_db71f_row7_col3 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_db71f_row7_col6 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_db71f_row8_col0 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_db71f_row8_col1 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_db71f_row8_col2 {
#   background-color: #1e9a51;
#   color: #f1f1f1;
# }
# #T_db71f_row8_col3 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_db71f_row8_col4 {
#   background-color: #84ca66;
#   color: #000000;
# }
# </style>
# <table id="T_db71f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db71f_level0_col0" class="col_heading level0 col0" >Productivity</th>
#       <th id="T_db71f_level0_col1" class="col_heading level0 col1" >Employment</th>
#       <th id="T_db71f_level0_col2" class="col_heading level0 col2" >Population</th>
#       <th id="T_db71f_level0_col3" class="col_heading level0 col3" >Gdp</th>
#       <th id="T_db71f_level0_col4" class="col_heading level0 col4" >Compensation</th>
#       <th id="T_db71f_level0_col5" class="col_heading level0 col5" >TaxesIncomeWealth</th>
#       <th id="T_db71f_level0_col6" class="col_heading level0 col6" >CapitalFormation</th>
#       <th id="T_db71f_level0_col7" class="col_heading level0 col7" >CapitalStock</th>
#       <th id="T_db71f_level0_col8" class="col_heading level0 col8" >earlyLeavers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db71f_level0_row0" class="row_heading level0 row0" >Productivity</th>
#       <td id="T_db71f_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_db71f_row0_col1" class="data row0 col1" >-0.28</td>
#       <td id="T_db71f_row0_col2" class="data row0 col2" >-0.84</td>
#       <td id="T_db71f_row0_col3" class="data row0 col3" >-0.69</td>
#       <td id="T_db71f_row0_col4" class="data row0 col4" >-0.72</td>
#       <td id="T_db71f_row0_col5" class="data row0 col5" >0.51</td>
#       <td id="T_db71f_row0_col6" class="data row0 col6" >0.12</td>
#       <td id="T_db71f_row0_col7" class="data row0 col7" >-0.66</td>
#       <td id="T_db71f_row0_col8" class="data row0 col8" >-0.77</td>
#     </tr>
#     <tr>
#       <th id="T_db71f_level0_row1" class="row_heading level0 row1" >Employment</th>
#       <td id="T_db71f_row1_col0" class="data row1 col0" >-0.28</td>
#       <td id="T_db71f_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_db71f_row1_col2" class="data row1 col2" >0.29</td>
#       <td id="T_db71f_row1_col3" class="data row1 col3" >0.75</td>
#       <td id="T_db71f_row1_col4" class="data row1 col4" >0.73</td>
#       <td id="T_db71f_row1_col5" class="data row1 col5" >-0.05</td>
#       <td id="T_db71f_row1_col6" class="data row1 col6" >0.79</td>
#       <td id="T_db71f_row1_col7" class="data row1 col7" >0.35</td>
#       <td id="T_db71f_row1_col8" class="data row1 col8" >-0.08</td>
#     </tr>
#     <tr>
#       <th id="T_db71f_level0_row2" class="row_heading level0 row2" >Population</th>
#       <td id="T_db71f_row2_col0" class="data row2 col0" >-0.84</td>
#       <td id="T_db71f_row2_col1" class="data row2 col1" >0.29</td>
#       <td id="T_db71f_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_db71f_row2_col3" class="data row2 col3" >0.71</td>
#       <td id="T_db71f_row2_col4" class="data row2 col4" >0.71</td>
#       <td id="T_db71f_row2_col5" class="data row2 col5" >-0.31</td>
#       <td id="T_db71f_row2_col6" class="data row2 col6" >-0.03</td>
#       <td id="T_db71f_row2_col7" class="data row2 col7" >0.85</td>
#       <td id="T_db71f_row2_col8" class="data row2 col8" >0.80</td>
#     </tr>
#     <tr>
#       <th id="T_db71f_level0_row3" class="row_heading level0 row3" >Gdp</th>
#       <td id="T_db71f_row3_col0" class="data row3 col0" >-0.69</td>
#       <td id="T_db71f_row3_col1" class="data row3 col1" >0.75</td>
#       <td id="T_db71f_row3_col2" class="data row3 col2" >0.71</td>
#       <td id="T_db71f_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_db71f_row3_col4" class="data row3 col4" >0.97</td>
#       <td id="T_db71f_row3_col5" class="data row3 col5" >-0.49</td>
#       <td id="T_db71f_row3_col6" class="data row3 col6" >0.31</td>
#       <td id="T_db71f_r

# %%
# display correlation
df.columns = labels
mat = df.corr(method = "spearman").round(2)
plt.figure(figsize = (8,6)) # width, height
sns.heatmap(mat, cmap = "RdYlGn", vmin = -1, vmax = 1, annot = True, square = True, fmt = "0.2f")
plt.show()

# %%
jrc_labels
# Out:
# ['SOVGDE',
#  'SNETD',
#  'SNPTD',
#  'SUVGD',
#  'RUWCD',
#  'RUYNH',
#  'RUIGT',
#  'ROKND',
#  'RPDNN']

# %%
# display correlation
df.columns = jrc_labels
mat = df.corr(method = "spearman").round(2)

mat.style.background_gradient(cmap = "RdYlGn").format("{:.2f}")
# Out:
# <style type="text/css">
# #T_beab3_row0_col0, #T_beab3_row1_col1, #T_beab3_row2_col2, #T_beab3_row3_col3, #T_beab3_row4_col4, #T_beab3_row5_col5, #T_beab3_row6_col6, #T_beab3_row7_col7, #T_beab3_row8_col8 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_beab3_row0_col1, #T_beab3_row0_col2, #T_beab3_row0_col3, #T_beab3_row0_col4, #T_beab3_row0_col7, #T_beab3_row0_col8, #T_beab3_row2_col0, #T_beab3_row8_col5, #T_beab3_row8_col6 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_beab3_row0_col5, #T_beab3_row8_col7 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_beab3_row0_col6 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_beab3_row1_col0 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_beab3_row1_col2 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_beab3_row1_col3 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_beab3_row1_col4, #T_beab3_row3_col2, #T_beab3_row4_col2 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_beab3_row1_col5 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_beab3_row1_col6 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_beab3_row1_col7, #T_beab3_row5_col6 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_beab3_row1_col8 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_beab3_row2_col1 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_beab3_row2_col3, #T_beab3_row2_col4 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_beab3_row2_col5 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_beab3_row2_col6 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_beab3_row2_col7 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_beab3_row2_col8 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_beab3_row3_col0 {
#   background-color: #cc2627;
#   color: #f1f1f1;
# }
# #T_beab3_row3_col1 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_beab3_row3_col4, #T_beab3_row4_col3 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_beab3_row3_col5 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_beab3_row3_col6 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_beab3_row3_col7, #T_beab3_row7_col8 {
#   background-color: #9bd469;
#   color: #000000;
# }
# #T_beab3_row3_col8 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_beab3_row4_col0 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_beab3_row4_col1 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_beab3_row4_col5 {
#   background-color: #bd1726;
#   color: #f1f1f1;
# }
# #T_beab3_row4_col6 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_beab3_row4_col7 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_beab3_row4_col8, #T_beab3_row7_col4 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_beab3_row5_col0 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_beab3_row5_col1 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_beab3_row5_col2 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_beab3_row5_col3 {
#   background-color: #dc3b2c;
#   color: #f1f1f1;
# }
# #T_beab3_row5_col4 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_beab3_row5_col7 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_beab3_row5_col8 {
#   background-color: #d22b27;
#   color: #f1f1f1;
# }
# #T_beab3_row6_col0 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_beab3_row6_col1 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_beab3_row6_col2, #T_beab3_row7_col5 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_beab3_row6_col3, #T_beab3_row6_col4 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_beab3_row6_col5 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_beab3_row6_col7 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_beab3_row6_col8 {
#   background-color: #e44c34;
#   color: #f1f1f1;
# }
# #T_beab3_row7_col0 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_beab3_row7_col1 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_beab3_row7_col2 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_beab3_row7_col3 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_beab3_row7_col6 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_beab3_row8_col0 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_beab3_row8_col1 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_beab3_row8_col2 {
#   background-color: #1e9a51;
#   color: #f1f1f1;
# }
# #T_beab3_row8_col3 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_beab3_row8_col4 {
#   background-color: #84ca66;
#   color: #000000;
# }
# </style>
# <table id="T_beab3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_beab3_level0_col0" class="col_heading level0 col0" >SOVGDE</th>
#       <th id="T_beab3_level0_col1" class="col_heading level0 col1" >SNETD</th>
#       <th id="T_beab3_level0_col2" class="col_heading level0 col2" >SNPTD</th>
#       <th id="T_beab3_level0_col3" class="col_heading level0 col3" >SUVGD</th>
#       <th id="T_beab3_level0_col4" class="col_heading level0 col4" >RUWCD</th>
#       <th id="T_beab3_level0_col5" class="col_heading level0 col5" >RUYNH</th>
#       <th id="T_beab3_level0_col6" class="col_heading level0 col6" >RUIGT</th>
#       <th id="T_beab3_level0_col7" class="col_heading level0 col7" >ROKND</th>
#       <th id="T_beab3_level0_col8" class="col_heading level0 col8" >RPDNN</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_beab3_level0_row0" class="row_heading level0 row0" >SOVGDE</th>
#       <td id="T_beab3_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_beab3_row0_col1" class="data row0 col1" >-0.28</td>
#       <td id="T_beab3_row0_col2" class="data row0 col2" >-0.84</td>
#       <td id="T_beab3_row0_col3" class="data row0 col3" >-0.69</td>
#       <td id="T_beab3_row0_col4" class="data row0 col4" >-0.72</td>
#       <td id="T_beab3_row0_col5" class="data row0 col5" >0.51</td>
#       <td id="T_beab3_row0_col6" class="data row0 col6" >0.12</td>
#       <td id="T_beab3_row0_col7" class="data row0 col7" >-0.66</td>
#       <td id="T_beab3_row0_col8" class="data row0 col8" >-0.77</td>
#     </tr>
#     <tr>
#       <th id="T_beab3_level0_row1" class="row_heading level0 row1" >SNETD</th>
#       <td id="T_beab3_row1_col0" class="data row1 col0" >-0.28</td>
#       <td id="T_beab3_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_beab3_row1_col2" class="data row1 col2" >0.29</td>
#       <td id="T_beab3_row1_col3" class="data row1 col3" >0.75</td>
#       <td id="T_beab3_row1_col4" class="data row1 col4" >0.73</td>
#       <td id="T_beab3_row1_col5" class="data row1 col5" >-0.05</td>
#       <td id="T_beab3_row1_col6" class="data row1 col6" >0.79</td>
#       <td id="T_beab3_row1_col7" class="data row1 col7" >0.35</td>
#       <td id="T_beab3_row1_col8" class="data row1 col8" >-0.08</td>
#     </tr>
#     <tr>
#       <th id="T_beab3_level0_row2" class="row_heading level0 row2" >SNPTD</th>
#       <td id="T_beab3_row2_col0" class="data row2 col0" >-0.84</td>
#       <td id="T_beab3_row2_col1" class="data row2 col1" >0.29</td>
#       <td id="T_beab3_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_beab3_row2_col3" class="data row2 col3" >0.71</td>
#       <td id="T_beab3_row2_col4" class="data row2 col4" >0.71</td>
#       <td id="T_beab3_row2_col5" class="data row2 col5" >-0.31</td>
#       <td id="T_beab3_row2_col6" class="data row2 col6" >-0.03</td>
#       <td id="T_beab3_row2_col7" class="data row2 col7" >0.85</td>
#       <td id="T_beab3_row2_col8" class="data row2 col8" >0.80</td>
#     </tr>
#     <tr>
#       <th id="T_beab3_level0_row3" class="row_heading level0 row3" >SUVGD</th>
#       <td id="T_beab3_row3_col0" class="data row3 col0" >-0.69</td>
#       <td id="T_beab3_row3_col1" class="data row3 col1" >0.75</td>
#       <td id="T_beab3_row3_col2" class="data row3 col2" >0.71</td>
#       <td id="T_beab3_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_beab3_row3_col4" class="data row3 col4" >0.97</td>
#       <td id="T_beab3_row3_col5" class="data row3 col5" >-0.49</td>
#       <td id="T_beab3_row3_col6" class="data row3 col6" >0.31</td>
#       <td id="T_beab3_row3_col7" class="data row3 col7" >0.53</td>
#       <td id="T_beab3_row3_c

# %%
# display correlation
df.columns = jrc_labels
mat = df.corr(method = "spearman").round(2)
plt.figure(figsize = (8,6)) # width, height
sns.heatmap(mat, cmap = "RdYlGn", vmin = -1, vmax = 1, annot = True, square = True, fmt = "0.2f")
plt.show()

# %%
# Number of columns in the plot grid
cols = 2

# Number of rows needed based on the number of columns in df
rows = (len(df.columns) - 1) // cols + 1  # Minus 1 to exclude the first column (time or index column)

# Create the subplots grid
fig, axes = plt.subplots(rows, cols, figsize=(10, rows * 4))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Loop through the columns and plot each on a separate subplot
df.columns = labels
for idx, val in enumerate(df.columns[1:]):
    ax = axes[idx]  # Select the appropriate subplot
    ax.plot(df.index, df[val])
    ax.set_xlabel('Time')
    ax.set_ylabel('Value')
    ax.set_title(val + ' Time Series Data')
    ax.tick_params(axis='x', rotation=45)

# Remove any extra subplots (if there are more subplots than columns)
for idx in range(len(df.columns) - 1, len(axes)):
    fig.delaxes(axes[idx])

# Adjust the layout to prevent overlapping
plt.tight_layout()

# Show the plot
plt.show()
